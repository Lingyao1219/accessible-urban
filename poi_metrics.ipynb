# %%
import os
import ast
import datetime
import pandas as pd
import statistics

nacis = pd.read_csv('google_categories_annotation.csv')
naics_dict = dict(zip(nacis['category'], nacis['3-digit NAICS Code']))

def get_place_metrics(df, gmap_id):
    """Get metrics for a place given its gmap_id."""
    data = df[df['gmap_id']==gmap_id]
    total_reviews = data.shape[0]
    avg_sentiment = data['sentiment_value'].mean()
    avg_rating = data['rating'].mean()
    return [gmap_id, total_reviews, avg_sentiment, avg_rating]

def process_state(df):
    """Process the state file and return a dataframe with metrics for each place."""
    df['sentiment_value'] = df['sentiment'].apply(lambda x: 1 if x == 'positive' else (0 if x == 'neutral' else -1))
    #df['time'] = df['time'].apply(lambda ts: datetime.datetime.fromtimestamp(ts/1000))
    gmap_ids = list(set(df['gmap_id'].to_list()))
    place_metrics = []
    for gmap_id in gmap_ids:
        metrics = get_place_metrics(df, gmap_id)
        place_metrics.append(metrics)
    columns=['gmap_id', 'total_accessible_reviews', 'avg_accessible_sentiment', 'avg_accessible_rating']
    metrics_df = pd.DataFrame(place_metrics, columns = columns)
    return metrics_df


def map_category(category):
    """Map the Google categories to NAICS code."""
    try:
        # Check if category is a string and needs evaluation
        if isinstance(category, str):
            lst = ast.literal_eval(category)
        else:
            lst = category  # Assume it's already a list

        lst = [i.replace("'", "") for i in lst]
        naics_codes = []
        for i in lst:
            if i in naics_dict:
                naics_codes.append(int(naics_dict[i]))
            else:
                continue
        mode = statistics.mode(naics_codes)
        if naics_codes.count(mode) == 1:
            return mode
        else:
            return naics_codes[0]
    except:
        return None

# %%
sentiment_folder = "accessible-review-merged-result"
sentiment_filenames = os.listdir(sentiment_folder)
sentiment_filenames = sorted(sentiment_filenames)

meta_folder = "accessible-meta"
meta_filenames = os.listdir(meta_folder)
meta_filenames = sorted(meta_filenames)

save_folder = "accessible-poi-metrics"
if not os.path.exists(save_folder):
    os.makedirs(save_folder)

for sentiment_file, meta_file in zip(sentiment_filenames, meta_filenames):
    sentiment_filepath = os.path.join(sentiment_folder, sentiment_file)
    meta_filepath = os.path.join(meta_folder, meta_file)
    print(f"----- processing: {sentiment_filepath}-{meta_filepath} -----")
    
    # Read poi-review sentiment file
    df = pd.read_json(sentiment_filepath, lines=True)
    for col in df.select_dtypes(include='object').columns:
        df[col] = df[col].apply(lambda x: str(x) if isinstance(x, (list, dict)) else x)
    df = df.drop_duplicates()
    df = df.rename(columns={'label': 'sentiment'})
    df = df[df['sentiment']!='unrelated']
    print(len(df))
    metrics_df = process_state(df)

    # Read poi-meta file
    meta_df = pd.read_json(meta_filepath, lines=True)
    meta_df = meta_df.drop_duplicates(subset='gmap_id', keep='first')
    merge_df = pd.merge(metrics_df, meta_df, on='gmap_id', how='left')
    merge_df['naics_code'] = merge_df['category'].apply(map_category)
    #merge_df = merge_df.dropna(subset=['naics_code'])
    save_file = sentiment_filepath.split('/')[1].split('.')[0] + "-results.jsonl"
    save_path = os.path.join(save_folder, save_file)    
    merge_df.to_json(save_path, orient='records', lines=True)
# Out:
# ----- processing: accessible-review-merged-result/review-Alabama-prediction.jsonl-accessible-meta/filtered_meta-Alabama.jsonl -----
# 5929
# ----- processing: accessible-review-merged-result/review-Alaska-prediction.jsonl-accessible-meta/filtered_meta-Alaska.jsonl -----
# 833
# ----- processing: accessible-review-merged-result/review-Arizona-prediction.jsonl-accessible-meta/filtered_meta-Arizona.jsonl -----
# 14444
# ----- processing: accessible-review-merged-result/review-Arkansas-prediction.jsonl-accessible-meta/filtered_meta-Arkansas.jsonl -----
# 3830
# ----- processing: accessible-review-merged-result/review-California-prediction.jsonl-accessible-meta/filtered_meta-California.jsonl -----
# 45812
# ----- processing: accessible-review-merged-result/review-Colorado-prediction.jsonl-accessible-meta/filtered_meta-Colorado.jsonl -----
# 12409
# ----- processing: accessible-review-merged-result/review-Connecticut-prediction.jsonl-accessible-meta/filtered_meta-Connecticut.jsonl -----
# 3487
# ----- processing: accessible-review-merged-result/review-Delaware-prediction.jsonl-accessible-meta/filtered_meta-Delaware.jsonl -----
# 1250
# ----- processing: accessible-review-merged-result/review-District_of_Columbia-prediction.jsonl-accessible-meta/filtered_meta-District_of_Columbia.jsonl -----
# 1404
# ----- processing: accessible-review-merged-result/review-Florida-prediction.jsonl-accessible-meta/filtered_meta-Florida.jsonl -----
# 43148
# ----- processing: accessible-review-merged-result/review-Georgia-prediction.jsonl-accessible-meta/filtered_meta-Georgia.jsonl -----
# 14488
# ----- processing: accessible-review-merged-result/review-Hawaii-prediction.jsonl-accessible-meta/filtered_meta-Hawaii.jsonl -----
# 2217
# ----- processing: accessible-review-merged-result/review-Idaho-prediction.jsonl-accessible-meta/filtered_meta-Idaho.jsonl -----
# 2866
# ----- processing: accessible-review-merged-result/review-Illinois-prediction.jsonl-accessible-meta/filtered_meta-Illinois.jsonl -----
# 13398
# ----- processing: accessible-review-merged-result/review-Indiana-prediction.jsonl-accessible-meta/filtered_meta-Indiana.jsonl -----
# 8745
# ----- processing: accessible-review-merged-result/review-Iowa-prediction.jsonl-accessible-meta/filtered_meta-Iowa.jsonl -----
# 3559
# ----- processing: accessible-review-merged-result/review-Kansas-prediction.jsonl-accessible-meta/filtered_meta-Kansas.jsonl -----
# 3775
# ----- processing: accessible-review-merged-result/review-Kentucky-prediction.jsonl-accessible-meta/filtered_meta-Kentucky.jsonl -----
# 5829
# ----- processing: accessible-review-merged-result/review-Louisiana-prediction.jsonl-accessible-meta/filtered_meta-Louisiana.jsonl -----
# 4228
# ----- processing: accessible-review-merged-result/review-Maine-prediction.jsonl-accessible-meta/filtered_meta-Maine.jsonl -----
# 1918
# ----- processing: accessible-review-merged-result/review-Maryland-prediction.jsonl-accessible-meta/filtered_meta-Maryland.jsonl -----
# 7253
# ----- processing: accessible-review-merged-result/review-Massachusetts-prediction.jsonl-accessible-meta/filtered_meta-Massachusetts.jsonl -----
# 7278
# ----- processing: accessible-review-merged-result/review-Michigan-prediction.jsonl-accessible-meta/filtered_meta-Michigan.jsonl -----
# 13894
# ----- processing: accessible-review-merged-result/review-Minnesota-prediction.jsonl-accessible-meta/filtered_meta-Minnesota.jsonl -----
# 6430
# ----- processing: accessible-review-merged-result/review-Mississippi-prediction.jsonl-accessible-meta/filtered_meta-Mississippi.jsonl -----
# 2499
# ----- processing: accessible-review-merged-result/review-Missouri-prediction.jsonl-accessible-meta/filtered_meta-Missouri.jsonl -----
# 11131
# ----- processing: accessible-review-merged-result/review-Montana-prediction.jsonl-accessible-meta/filtered_meta-Montana.jsonl -----
# 1601
# ----- processing: accessible-review-merged-result/review-Nebraska-prediction.jsonl-accessible-meta/filtered_meta-Nebraska.jsonl -----
# 2107
# ----- processing: accessible-review-merged-result/review-Nevada-prediction.jsonl-accessible-meta/filtered_meta-Nevada.jsonl -----
# 6550
# ----- processing: accessible-review-merged-result/review-New_Hampshire-prediction.jsonl-accessible-meta/filtered_meta-New_Hampshire.jsonl -----
# 2251
# ----- processing: accessible-review-merged-result/review-New_Jersey-prediction.jsonl-accessible-meta/filtered_meta-New_Jersey.jsonl -----
# 8549
# ----- processing: accessible-review-merged-result/review-New_Mexico-prediction.jsonl-accessible-meta/filtered_meta-New_Mexico.jsonl -----
# 4503
# ----- processing: accessible-review-merged-result/review-New_York-prediction.jsonl-accessible-meta/filtered_meta-New_York.jsonl -----
# 21345
# ----- processing: accessible-review-merged-result/review-North_Carolina-prediction.jsonl-accessible-meta/filtered_meta-North_Carolina.jsonl -----
# 15844
# ----- processing: accessible-review-merged-result/review-North_Dakota-prediction.jsonl-accessible-meta/filtered_meta-North_Dakota.jsonl -----
# 649
# ----- processing: accessible-review-merged-result/review-Ohio-prediction.jsonl-accessible-meta/filtered_meta-Ohio.jsonl -----
# 16195
# ----- processing: accessible-review-merged-result/review-Oklahoma-prediction.jsonl-accessible-meta/filtered_meta-Oklahoma.jsonl -----
# 6046
# ----- processing: accessible-review-merged-result/review-Oregon-prediction.jsonl-accessible-meta/filtered_meta-Oregon.jsonl -----
# 10684
# ----- processing: accessible-review-merged-result/review-Pennsylvania-prediction.jsonl-accessible-meta/filtered_meta-Pennsylvania.jsonl -----
# 16784
# ----- processing: accessible-review-merged-result/review-Rhode_Island-prediction.jsonl-accessible-meta/filtered_meta-Rhode_Island.jsonl -----
# 1237
# ----- processing: accessible-review-merged-result/review-South_Carolina-prediction.jsonl-accessible-meta/filtered_meta-South_Carolina.jsonl -----
# 8472
# ----- processing: accessible-review-merged-result/review-South_Dakota-prediction.jsonl-accessible-meta/filtered_meta-South_Dakota.jsonl -----
# 1142
# ----- processing: accessible-review-merged-result/review-Tennessee-prediction.jsonl-accessible-meta/filtered_meta-Tennessee.jsonl -----
# 12174
# ----- processing: accessible-review-merged-result/review-Texas-prediction.jsonl-accessible-meta/filtered_meta-Texas.jsonl -----
# 38287
# ----- processing: accessible-review-merged-result/review-Utah-prediction.jsonl-accessible-meta/filtered_meta-Utah.jsonl -----
# 6026
# ----- processing: accessible-review-merged-result/review-Vermont-prediction.jsonl-accessible-meta/filtered_meta-Vermont.jsonl -----
# 782
# ----- processing: accessible-review-merged-result/review-Virginia-prediction.jsonl-accessible-meta/filtered_meta-Virginia.jsonl -----
# 2096
# ----- processing: accessible-review-merged-result/review-Washington-prediction.jsonl-accessible-meta/filtered_meta-Washington.jsonl -----
# 13767
# ----- processing: accessible-review-merged-result/review-West_Virginia-prediction.jsonl-accessible-meta/filtered_meta-West_Virginia.jsonl -----
# 2055
# ----- processing: accessible-review-merged-result/review-Wisconsin-prediction.jsonl-accessible-meta/filtered_meta-Wisconsin.jsonl -----
# 7835
# ----- processing: accessible-review-merged-result/review-Wyoming-prediction.jsonl-accessible-meta/filtered_meta-Wyoming.jsonl -----
# 1048
